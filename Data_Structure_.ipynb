# %% [markdown]
# # Data Types and structures

# %% [markdown]
# ### Assignment of Data Types and Structures Theory Questions

# %% [markdown]
# 1. what are data structures, and why are they impoartant?
#
# -> the data structure are the way of organizin and storing data so that can easy to accessing or manipulating data.
# they are imp because that help to manage the data storing a data.

# %% [markdown]
# 2. explain the difference between mutable and immutable data type with examples?
#
# -> Mutable : can be change after creation Exp(list, dict, set)
# Immutable : cannot be change after creation Exp(tuple, str, int).

# %% [markdown]
# 3. what are the main differance between lists and tuple in python?
#
# -> lists are mutuable:tuple are the immutable.
# data type change;fixed data
# enclosed in ([]) brackets; enclosed in () brackets.

# %% [markdown]
# 4. Describle how dictionaries store data?
#
# -> dictionaries store data in key-value pairs it easy to fast access by keys.

# %% [markdown]
# 5. why might you use a set instead of a list in python?
#
# -> sets automatically remove duplicates value and offer faster membership checks.

# %% [markdown]
# 6. what is a string in python,and how is it different from a list?
#
# -> the string is the sequence of characters the string are the immutable while the list are orerded collection of items that can ba different type and is mutable.

# %% [markdown]
# 7. how to tuple ensure data intergrity in python?
#
# -> the tuple are the immutuable they donot conatin a new elements ensuring they remain constant

# %% [markdown]
# 8. what is a hash table, and how does it relate to dictionaries in python?
#
# -> a hash table is a data structure that maps keys to values using a hash function python dictionaries use hash table internally.

# %% [markdown]
# 9. can lists contain different data type in python?
#
# -> yes lists can contain elements of different types Exp strings, numbers float, boolean, complex.

# %% [markdown]
# 10. Explain why string are immutable in python?
#
# -> string are immutable to ensure consistency and security and optimize memory and perfromace through string interning.

# %% [markdown]
# 11. what advantages do dictionaries offer over lits for certain tasks?
#
# -> dictionaries allow fast lookups, update, and deletion using keys, unlike lists which require sequential searches.

# %% [markdown]
# 12. describe a scenario where using a tuple would be preferable over a list.
#
# -> when storing fixed data that should not change, like coordinates (x,y) or days fo the week.

# %% [markdown]
# 13. how do sets handle duplicate value in python?
#
# -> sets automatically discard dupliacte values and only store unique items.

# %% [markdown]
# 14 how does the "in" keyword work differentily for lists and dictionaries?
#
# -> for lists in checks for the presence of a value;for dictionaries, it checks for the prsence of a kay.

# %% [markdown]
# 15. can you modify the elements of a tuple? explain why or why not.
#
# -> no tuple are the immutable, so their elements cannot be changed after creation.

# %% [markdown]
# 16. what is a nested dictionary, and give an example of its use case?
#
# -> a nested dictionary is a dictionary where the value of a key is another dictionary.

# %% [markdown]
# 17. describe the time complexity of accessing elements in a dictionary
#
# -> accessing elements by key in adictionary has average time complexity of 0(1), thanks to the hash table implementation.

# %% [markdown]
# 18. in what situations are the lists preferred over dictionaries?
#
# -> order matters
# you need to store itmes without keys
# the data is simple and linear

# %% [markdown]
# 19. why are dictionaries considered comsider unordered, and how does that affect data retriveval?
#
# -> dictionaries are considered unordered though from python 3.7+, insertion oder is preserved because their primary design is based on hashing not sequence this means data retrieval is based on keys not position.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval?
#
# -> list: accessed by index Exp my_list[0]
# dictionary accessed by keys Exp my_dict["name"] dictionaries offer faster lookups when using unqiue keys while list are better for ordered sequences.

# %% [markdown]
# # practical Questions

# %%
# creating a string with yours name and print it
name = "kartik"
print(name)
# Out:
# kartik

# %%
# find the length of the string "Hello world"
str = "Hello World"
print(len(str))
# Out:
# 11

# %%
# slice the first 3 characters from "python programming"
text = "python programming"
text[0:3]
# Out:
# 'pyt'

# %%
# converting string "hello" to uppercase
s = "hello"
s.upper()
# Out:
# 'HELLO'

# %%
# replace 'apple' with 'orange' in 'i like apple'
sentence = "i like apple"
print(sentence.replace("apple", "orange"))
# Out:
# i like orange

# %%
# create a list with numbers 1 t0 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# append number 10 the list [1, 2, 3, 4]
list = [1, 2, 3, 4,]
list.append(10)
list
# Out:
# [1, 2, 3, 4, 10]

# %%
list = [1, 2, 3, 4, 5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
# access the second element in the ["a", "b", "c", "d"]
chars = ["a", "b", "c", "d"]
chars[1]
# Out:
# 'b'

# %%
# reverse the list[10, 20, 30, 40, 50]
list = [10, 20, 30, 40, 50]
list[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#creating a tuple with elements 100, 200, 300 and print it
tuple = (100, 200, 300)
tuple
# Out:
# (100, 200, 300)

# %%
# access least second elements of tuple ("red", "green", "blue", "yellow")
colors = ("red", "green", "blue", "yellow")
colors[-2]
# Out:
# 'blue'

# %%
# find the minimum number in tuple (10, 20, 5, 15)
t = (10, 20, 5, 15)
min(t)
# Out:
# 5

# %%
# find index of "cat" in ("dog", "cat", "rabbit")
animals = ("dog", "cat", "rabbit")
animals.index("cat")
# Out:
# 1

# %%
# creating a tuple of 3 fruits and check if is in it
frutis = ("apple", "banana", "mango")
"kiwi" in frutis
# Out:
# False

# %%
# creating a set with "a", "b", "c"
s = {"a", "b", "c"}
s
# Out:
# {'a', 'b', 'c'}

# %%
# clear the elements from the set {1, 2, 3, 4, 5}
s = {1, 2, 3, 4, 5}
s.clear()
s
# Out:
# set()

# %%
# remove elements 4 from the set {1, 2, 3, 4}
s = {1, 2, 3, 4}
s.remove(4)
s
# Out:
# {1, 2, 3}

# %%
# find the union of {1,2,3} and {3, 4, 5}
a = {1, 2, 3}
b = {3, 4, 5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
# find intersection  of {1, 2, 3} and {2, 3, 4}
a = {1, 2, 3}
b = {2, 3, 4}
a.intersection(b)
# Out:
# {2, 3}

# %%
person = {"name": "sunskruti", "age" : 34, "city" : "landon"}
person
# Out:
# {'name': 'sunskruti', 'age': 34, 'city': 'landon'}

# %%
d = {"name" : "kartik", "age" : 25}
d["country"] = "India"
d
# Out:
# {'name': 'kartik', 'age': 25, 'country': 'India'}

# %%
d = {"name" : "sahil", "age" : 22}
d["name"]
# Out:
# 'sahil'

# %%
d = {"name" : "joan", "age" : 18, "city" : "new_york"}
d.pop("age")
d
# Out:
# {'name': 'joan', 'city': 'new_york'}

# %%
d = {"name" : "urvi", "city" : "paris"}
"city" in d
# Out:
# True

# %%
my_list = [1, 2, 3]
my_tuple = (22, 44, 55)
my_dict = {"a" : 1, "b" : 2}
print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3]
# (22, 44, 55)
# {'a': 1, 'b': 2}

# %%
import random
numbers = random.sample(range(1,101),5)
numbers.sort()
numbers
# Out:
# [10, 14, 31, 74, 88]

# %%
words = ["apple", "banana", "cherry", "data", "fig"]
words[3]
# Out:
# 'data'

# %%
dict1 = {"a":1, "b":2}
dict2 = {"c":3, "d":4}
print(dict1, dict2)
# Out:
# {'a': 1, 'b': 2} {'c': 3, 'd': 4}

# %%
string_list = ["apple","banana", "cherry", "apple"]
string_set = set(string_list)
print(string_set)
# Out:
# {'cherry', 'banana', 'apple'}
